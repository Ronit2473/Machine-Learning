# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dt = pd.read_csv(r'xAPI-Edu-Data.csv')
dt
# Out:
#     gender       StageID SectionID Relation Semester      Topic  raisedhands  \
# 0        M    lowerlevel         A   Father        F         IT           15
# 1        M    lowerlevel         A   Father        F         IT           20
# 2        M    lowerlevel         A   Father        F         IT           10
# 3        M    lowerlevel         A   Father        F         IT           30
# 4        M    lowerlevel         A   Father        F         IT           40
# ..     ...           ...       ...      ...      ...        ...          ...
# 475      F  MiddleSchool         A   Father        S  Chemistry            5
# 476      F  MiddleSchool         A   Father        F    Geology           50
# 477      F  MiddleSchool         A   Father        S    Geology           55
# 478      F  MiddleSchool         A   Father        F    History           30
# 479      F  MiddleSchool         A   Father        S    History           35
#
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   StageID                   480 non-null    object
#  2   SectionID                 480 non-null    object
#  3   Relation                  480 non-null    object
#  4   Semester                  480 non-null    object
#  5   Topic                     480 non-null    object
#  6   raisedhands               480 non-null    int64
#  7   VisITedResources          480 non-null    int64
#  8   AnnouncementsView         480 non-null    int64
#  9   Discussion                480 non-null    int64
#  10  ParentschoolSatisfaction  480 non-null    object
#  11  StudentAbsenceDays        480 non-null    object
#  12  Class                     480 non-null    object
# dtypes: int64(4), object(9)
# memory usage: 48.9+ KB

# %%
dt.describe(include="all")
# Out:
#        gender       StageID SectionID Relation Semester Topic  raisedhands  \
# count     480           480       480      480      480   480   480.000000
# unique      2             3         3        2        2    12          NaN
# top         M  MiddleSchool         A   Father        F    IT          NaN
# freq      305           248       283      283      245    95          NaN
# mean      NaN           NaN       NaN      NaN      NaN   NaN    46.775000
# std       NaN           NaN       NaN      NaN      NaN   NaN    30.779223
# min       NaN           NaN       NaN      NaN      NaN   NaN     0.000000
# 25%       NaN           NaN       NaN      NaN      NaN   NaN    15.750000
# 50%       NaN           NaN       NaN      NaN      NaN   NaN    50.000000
# 75%       NaN           NaN       NaN      NaN      NaN   NaN    75.000000
# max       NaN           NaN       NaN      NaN      NaN   NaN   100.000000
#
#         VisITedResources  AnnouncementsView  Discussion  \
# ...

# %%
print("No of duplicate records - ",dt.duplicated().sum())
print("% of Duplicate records - " , dt.duplicated().sum()/len(dt)*100)
# Out:
# No of duplicate records -  2
# % of Duplicate records -  0.4166666666666667

# %%
dt.drop_duplicates(inplace=True,keep="first")

# %%
dt
# Out:
#     gender       StageID SectionID Relation Semester      Topic  raisedhands  \
# 0        M    lowerlevel         A   Father        F         IT           15
# 1        M    lowerlevel         A   Father        F         IT           20
# 2        M    lowerlevel         A   Father        F         IT           10
# 3        M    lowerlevel         A   Father        F         IT           30
# 4        M    lowerlevel         A   Father        F         IT           40
# ..     ...           ...       ...      ...      ...        ...          ...
# 475      F  MiddleSchool         A   Father        S  Chemistry            5
# 476      F  MiddleSchool         A   Father        F    Geology           50
# 477      F  MiddleSchool         A   Father        S    Geology           55
# 478      F  MiddleSchool         A   Father        F    History           30
# 479      F  MiddleSchool         A   Father        S    History           35
#
# ...

# %%
dt.isnull().sum()
# Out:
# gender                      0
# StageID                     0
# SectionID                   0
# Relation                    0
# Semester                    0
# Topic                       0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
for i in dt.columns:
    print({i:dt[i].unique()})
# Out:
# {'gender': array(['M', 'F'], dtype=object)}
# {'StageID': array(['lowerlevel', 'MiddleSchool', 'HighSchool'], dtype=object)}
# {'SectionID': array(['A', 'B', 'C'], dtype=object)}
# {'Relation': array(['Father', 'Mum'], dtype=object)}
# {'Semester': array(['F', 'S'], dtype=object)}
# {'Topic': array(['IT', 'Math', 'Arabic', 'Science', 'English', 'Quran', 'Spanish',
#        'French', 'History', 'Biology', 'Chemistry', 'Geology'],
#       dtype=object)}
# {'raisedhands': array([ 15,  20,  10,  30,  40,  42,  35,  50,  12,  70,  19,   5,  62,
#         36,  55,  69,  60,   2,   0,   8,  25,  75,   4,  45,  14,  33,
#          7,  13,  29,  39,  49,  16,  28,  27,  21,  80,  17,  65,  22,
#         11,   1,   3, 100,   6,  90,  77,  24,  66,  23,  82,  72,  51,
#         85,  87,  95,  81,  53,  92,  83,  67,  96,  57,  73,   9,  32,
#         52,  59,  61,  79,  18,  74,  97,  41,  71,  98,  78,  89,  88,
#         86,  76,  99,  84], dtype=int64)}
# ...

# %%
dt.columns
# Out:
# Index(['gender', 'StageID', 'SectionID', 'Relation', 'Semester', 'Topic',
#        'raisedhands', 'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentschoolSatisfaction', 'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
dt.dtypes
# Out:
# gender                      object
# StageID                     object
# SectionID                   object
# Relation                    object
# Semester                    object
# Topic                       object
# raisedhands                  int64
# VisITedResources             int64
# AnnouncementsView            int64
# Discussion                   int64
# ParentschoolSatisfaction    object
# StudentAbsenceDays          object
# Class                       object
# dtype: object

# %%
dt.Topic.value_counts()
# Out:
# IT           95
# French       63
# Arabic       59
# Science      51
# English      45
# Biology      30
# Spanish      25
# Chemistry    24
# Geology      24
# Quran        22
# Math         21
# History      19
# Name: Topic, dtype: int64

# %%
dt["Institute"]="XYZ"
dt
# Out:
#     gender       StageID SectionID Relation Semester      Topic  raisedhands  \
# 0        M    lowerlevel         A   Father        F         IT           15
# 1        M    lowerlevel         A   Father        F         IT           20
# 2        M    lowerlevel         A   Father        F         IT           10
# 3        M    lowerlevel         A   Father        F         IT           30
# 4        M    lowerlevel         A   Father        F         IT           40
# ..     ...           ...       ...      ...      ...        ...          ...
# 475      F  MiddleSchool         A   Father        S  Chemistry            5
# 476      F  MiddleSchool         A   Father        F    Geology           50
# 477      F  MiddleSchool         A   Father        S    Geology           55
# 478      F  MiddleSchool         A   Father        F    History           30
# 479      F  MiddleSchool         A   Father        S    History           35
#
# ...

# %%
dt.drop(["Institute"],axis=1,inplace=True)

# %%
dt.drop(["SectionID",'Semester'],axis=1,inplace=True)

# %%
dt.drop(["Topic"],axis=1,inplace=True)

# %%
dt.hist(figsize=(15,7));

# %%
dt.columns
# Out:
# Index(['gender', 'StageID', 'Relation', 'raisedhands', 'VisITedResources',
#        'AnnouncementsView', 'Discussion', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
features = ['raisedhands','VisITedResources','AnnouncementsView','Discussion']

# %%
sns.pairplot(x_vars = features,y_vars=features,data=dt,hue="Class")

# %%
sns.countplot(data=dt,x="gender",palette="viridis",hue="Class")
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(data=dt,x="Relation",palette="Set1",hue="Class")
# Out:
# <Axes: xlabel='Relation', ylabel='count'>

# %%
sns.countplot(data=dt,x="StudentAbsenceDays",palette="Set2",hue="Class")
# Out:
# <Axes: xlabel='StudentAbsenceDays', ylabel='count'>

# %%
dt.isnull().sum()
# Out:
# gender                      0
# StageID                     0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
dt.Class.value_counts()
# Out:
# M    211
# H    142
# L    125
# Name: Class, dtype: int64

# %%
sns.countplot(data=dt,x="Class")
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
col=[]
for i in dt.columns:
    if dt[i].dtype=="object":
        col.append(i)
col
# Out:
# ['gender',
#  'StageID',
#  'Relation',
#  'ParentschoolSatisfaction',
#  'StudentAbsenceDays',
#  'Class']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for i in col[:-1]:
    dt[i]=le.fit_transform(dt[i])

    le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))

    print("Feature",i)
    print("maping",le_name_mapping)
    print("-------------------")
# Out:
# Feature gender
# maping {'F': 0, 'M': 1}
# -------------------
# Feature StageID
# maping {'HighSchool': 0, 'MiddleSchool': 1, 'lowerlevel': 2}
# -------------------
# Feature Relation
# maping {'Father': 0, 'Mum': 1}
# -------------------
# Feature ParentschoolSatisfaction
# maping {'Bad': 0, 'Good': 1}
# -------------------
# Feature StudentAbsenceDays
# maping {'Above-7': 0, 'Under-7': 1}
# -------------------

# %%
dt["Class"]=dt["Class"].map({"L":0,"M":1,"H":2})

# %%
dt
# Out:
#      gender  StageID  Relation  raisedhands  VisITedResources  \
# 0         1        2         0           15                16
# 1         1        2         0           20                20
# 2         1        2         0           10                 7
# 3         1        2         0           30                25
# 4         1        2         0           40                50
# ..      ...      ...       ...          ...               ...
# 475       0        1         0            5                 4
# 476       0        1         0           50                77
# 477       0        1         0           55                74
# 478       0        1         0           30                17
# 479       0        1         0           35                14
#
#      AnnouncementsView  Discussion  ParentschoolSatisfaction  \
# 0                    2          20                         1
# 1                    3          25                         1
# ...

# %%
sns.set()
Class_plot=dt["Class"].value_counts().plot(kind="bar")

# %%
Class_plot=dt["Class"].value_counts().plot(kind="pie",autopct="%.2f%%")

# %%
X=dt.values[:,0:-1]
Y=dt.values[:,-1]

# %%
print(X.shape)
print(X.shape)
# Out:
# (478, 9)
# (478, 9)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(X)
X=sc.transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LogisticRegression

#creating  a model
classifier = LogisticRegression()

#fitting training data to model
classifier.fit(X_train,Y_train) 
Y_pred=classifier.predict(X_test)
print(Y_pred)
# Out:
# [1 1 2 2 2 1 2 1 0 1 1 0 2 0 0 1 1 2 2 2 1 1 2 0 1 0 1 1 0 2 1 1 1 1 1 2 0
#  1 1 2 0 1 1 1 2 1 1 0 1 2 0 1 2 1 0 0 1 1 0 0 2 0 2 1 2 2 2 1 1 1 2 1 1 2
#  1 1 0 0 1 0 0 2 1 1 2 1 2 0 2 1 2 2 1 2 1 2]

# %%
np.set_printoptions(suppress=True)
Y_pred_prob = classifier.predict_proba(X_test)
Y_pred_prob
# Out:
# array([[0.00028488, 0.58558258, 0.41413254],
#        [0.92957884, 0.0700783 , 0.00034286],
#        [0.00870005, 0.60719406, 0.38410589],
#        [0.69165171, 0.30135227, 0.00699602],
#        [0.94092939, 0.05900851, 0.0000621 ],
#        [0.8692519 , 0.12947927, 0.00126883],
#        [0.00004634, 0.20387223, 0.79608143],
#        [0.0001711 , 0.37118658, 0.62864232],
#        [0.22983773, 0.72706213, 0.04310014],
#        [0.00110657, 0.44333585, 0.55555758],
#        [0.94760272, 0.05220498, 0.0001923 ],
#        [0.00045391, 0.54815194, 0.45139415],
#        [0.00002729, 0.11430164, 0.88567107],
#        [0.00002343, 0.09580341, 0.90417316],
#        [0.86609247, 0.1326139 , 0.00129363],
#        [0.00509054, 0.85301041, 0.14189905],
#        [0.0017455 , 0.59567768, 0.40257682],
#        [0.00028567, 0.19583812, 0.80387621],
#        [0.84287198, 0.15464595, 0.00248207],
#        [0.00123065, 0.47732159, 0.52144776],
#        [0.00016224, 0.16407866, 0.8357591 ],
# ...

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
 
cfm=confusion_matrix(Y_test,Y_pred)
print(cfm)
 
print("Classification report: ")
 
print(classification_report(Y_test,Y_pred))
 
acc=accuracy_score(Y_test, Y_pred) # Here the accuracy is good means the data is balanced
print("Accuracy of the model: ",acc)
# Out:
# [[20  4  0]
#  [ 1 35 11]
#  [ 0  6 19]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.83      0.89        24
#            1       0.78      0.74      0.76        47
#            2       0.63      0.76      0.69        25
#
#     accuracy                           0.77        96
#    macro avg       0.79      0.78      0.78        96
# weighted avg       0.78      0.77      0.77        96
#
# Accuracy of the model:  0.7708333333333334

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
 
cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()

print("Classification report: ")
 
print(classification_report(Y_test,Y_pred))
 
acc=accuracy_score(Y_test, Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.83      0.89        24
#            1       0.78      0.74      0.76        47
#            2       0.63      0.76      0.69        25
#
#     accuracy                           0.77        96
#    macro avg       0.79      0.78      0.78        96
# weighted avg       0.78      0.77      0.77        96
#
# Accuracy of the model:  0.7708333333333334

# %%
#predicting using the Decision_Tree_Classifier
from sklearn.tree import DecisionTreeClassifier

model_DecisionTree = DecisionTreeClassifier(criterion="gini",random_state=10)

#fit the model on the data and predict the values
model_DecisionTree.fit(X_train,Y_train)

Y_pred = model_DecisionTree.predict(X_test)
#print(Y_pred)
#print(list(zip(Y_test,Y_pred)))

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
 
cfm=confusion_matrix(Y_test,Y_pred)
print(cfm)
 
print("Classification report: ")
 
print(classification_report(Y_test,Y_pred))
 
acc=accuracy_score(Y_test, Y_pred) # Here the accuracy is good means the data is balanced
print("Accuracy of the model: ",acc)
# Out:
# [[18  6  0]
#  [ 3 32 12]
#  [ 0 10 15]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80        24
#            1       0.67      0.68      0.67        47
#            2       0.56      0.60      0.58        25
#
#     accuracy                           0.68        96
#    macro avg       0.69      0.68      0.68        96
# weighted avg       0.69      0.68      0.68        96
#
# Accuracy of the model:  0.6770833333333334

# %%
# print the scores on training and test set
print('Training set score: {:.4f}'.format(model_DecisionTree.score(X_train, Y_train)))

print('Test set score: {:.4f}'.format(model_DecisionTree.score(X_test, Y_test)))
# Out:
# Training set score: 0.9974
# Test set score: 0.6771

# %%
print(list(zip(dt.columns[0:-1],model_DecisionTree.feature_importances_)))
# Out:
# [('gender', 0.07026185715973857), ('StageID', 0.03563041716659457), ('Relation', 0.06155783183168858), ('raisedhands', 0.12811011652715856), ('VisITedResources', 0.2510595277099195), ('AnnouncementsView', 0.11766828197379207), ('Discussion', 0.12139297102589902), ('ParentschoolSatisfaction', 0.014705036896771455), ('StudentAbsenceDays', 0.19961395970843762)]

# %%
sample = pd.DataFrame()
sample["Column"]=dt.columns[0:-1]
sample["Imp_value"]=model_DecisionTree.feature_importances_
sample.sort_values("Imp_value",ascending=False)
# Out:
#                      Column  Imp_value
# 4          VisITedResources   0.251060
# 8        StudentAbsenceDays   0.199614
# 3               raisedhands   0.128110
# 6                Discussion   0.121393
# 5         AnnouncementsView   0.117668
# 0                    gender   0.070262
# 2                  Relation   0.061558
# 1                   StageID   0.035630
# 7  ParentschoolSatisfaction   0.014705

# %%
# plt.figure(figsize=(30,20))

# from sklearn import tree

# tree.plot_tree(model_DecisionTree.fit(X_train, Y_train));

# %%
from sklearn import tree
with open (r"model_decision.txt","w") as f:
    f=tree.export_graphviz(model_DecisionTree,feature_names=dt.columns[0:-1],out_file=f)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\abc\\Imarticus machine learning\\Decision Tree'

# %%
new_dt = dt.drop(["StageID","StageID","Relation"],axis=1)

# %%
x=dt.values[:,0:-1]
y=dt.values[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(x)
x=sc.transform(x)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#predicting using the Decision_Tree_Classifier
from sklearn.tree import DecisionTreeClassifier

model_DecisionTree = DecisionTreeClassifier(criterion="gini",random_state=42)

#fit the model on the data and predict the values
model_DecisionTree.fit(X_train,Y_train)

Y_pred = model_DecisionTree.predict(X_test)
#print(Y_pred)
#print(list(zip(Y_test,Y_pred)))

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
 
cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()

print("Classification report: ")
 
print(classification_report(Y_test,Y_pred))
 
acc=accuracy_score(Y_test, Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.85      0.81        27
#            1       0.73      0.60      0.66        45
#            2       0.62      0.75      0.68        24
#
#     accuracy                           0.71        96
#    macro avg       0.71      0.73      0.71        96
# weighted avg       0.71      0.71      0.71        96
#
# Accuracy of the model:  0.7083333333333334

# %%
model_DecisionTree = DecisionTreeClassifier(criterion="gini",random_state=42,splitter="best",min_samples_leaf=6,max_depth=15)

#fit the model on the data and predict the values
model_DecisionTree.fit(X_train,Y_train)

Y_pred = model_DecisionTree.predict(X_test)
#print(Y_pred)
#print(list(zip(Y_test,Y_pred)))

# %%
cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()

print("Classification report: ")
 
print(classification_report(Y_test,Y_pred))
 
acc=accuracy_score(Y_test, Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83        27
#            1       0.76      0.69      0.72        45
#            2       0.71      0.71      0.71        24
#
#     accuracy                           0.75        96
#    macro avg       0.75      0.76      0.75        96
# weighted avg       0.75      0.75      0.75        96
#
# Accuracy of the model:  0.75

# %%
print("training set score:{:.4f}".format(model_DecisionTree.score(X_train,Y_train)))
print("training set score:{:.4f}".format(model_DecisionTree.score(X_test,Y_test)))
# Out:
# training set score:0.8325
# training set score:0.7500

# %%
from sklearn.linear_model import LogisticRegression
lo=LogisticRegression()

# %%
from sklearn.ensemble import RandomForestClassifier
model_random=RandomForestClassifier(n_estimators=100,random_state=10,bootstrap=True)
model_random.fit(X_train,Y_train)
Y_pred=model_random.predict(X_test)

# %%
cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()

print("Classification report: ")
 
print(classification_report(Y_test,Y_pred))
 
acc=accuracy_score(Y_test, Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87        27
#            1       0.79      0.73      0.76        45
#            2       0.69      0.75      0.72        24
#
#     accuracy                           0.78        96
#    macro avg       0.78      0.79      0.78        96
# weighted avg       0.78      0.78      0.78        96
#
# Accuracy of the model:  0.78125

# %%
from sklearn.ensemble import RandomForestClassifier
model_random2=RandomForestClassifier(n_estimators=100,random_state=10,bootstrap=False)
model_random2.fit(X_train,Y_train)
Y_pred=model_random.predict(X_test)

# %%
cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()

print("Classification report: ")
 
print(classification_report(Y_test,Y_pred))
 
acc=accuracy_score(Y_test, Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87        27
#            1       0.79      0.73      0.76        45
#            2       0.69      0.75      0.72        24
#
#     accuracy                           0.78        96
#    macro avg       0.78      0.79      0.78        96
# weighted avg       0.78      0.78      0.78        96
#
# Accuracy of the model:  0.78125

# %%
model_RandomForest=RandomForestClassifier( random_state=10, bootstrap=True) #fixed parameters should be passsed here
 
#parameters for trial and error should be passed here
parameter_space = {
    'n_estimators':[100,300,500,1000],       
    'max_depth':[10,15,8, 12],
    'min_samples_leaf':[1,3,4,5,6,7]
    }
from sklearn.model_selection import RandomizedSearchCV #RandomizedSearchCV
clf = RandomizedSearchCV(model_RandomForest, parameter_space, n_jobs=-1, cv=5)

# %%
clf.fit(X_train,Y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=10),
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [10, 15, 8, 12],
#                                         'min_samples_leaf': [1, 3, 4, 5, 6, 7],
#                                         'n_estimators': [100, 300, 500, 1000]})

# %%
clf.best_params_
clf.best_score_
# Out:
# 0.7592617908407382

# %%
clf.best_params_
# Out:
# {'n_estimators': 1000, 'min_samples_leaf': 4, 'max_depth': 15}

# %%
Y_pred=clf.predict(X_test)
cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()

print("Classification report: ")
 
print(classification_report(Y_test,Y_pred))
 
acc=accuracy_score(Y_test, Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85        27
#            1       0.81      0.78      0.80        45
#            2       0.77      0.83      0.80        24
#
#     accuracy                           0.81        96
#    macro avg       0.81      0.82      0.82        96
# weighted avg       0.81      0.81      0.81        96
#
# Accuracy of the model:  0.8125
